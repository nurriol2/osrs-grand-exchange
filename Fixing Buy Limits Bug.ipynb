# %%
from osrsbox import items_api
import re
import json
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# # Proving that there is a problem #

# %%
#the three kinds of tradeable chinchompas
chinchompas = ["Chinchompa", "Red chinchompa", "Black chinchompa"]

# %%
#AllItems object
all_items = items_api.load()

# %%
def get_select_properties(item_name: str, select_properties: list =["id", "name", "buy_limit", "wiki_url"])->dict:
    """
    Query osrsbox-db for specific keys in the ItemProperties of an item
    """
    properties = all_items.lookup_by_item_name(item_name).construct_json()
    return {p:properties[p] for p in select_properties}

for c in chinchompas:
    print(f"{get_select_properties(c)}\n")
# Out:
# {'id': 9976, 'name': 'Chinchompa', 'buy_limit': None, 'wiki_url': 'https://oldschool.runescape.wiki/w/Chinchompa'}
#
# {'id': 9977, 'name': 'Red chinchompa', 'buy_limit': None, 'wiki_url': 'https://oldschool.runescape.wiki/w/Red_chinchompa'}
#
# {'id': 11959, 'name': 'Black chinchompa', 'buy_limit': 11000, 'wiki_url': 'https://oldschool.runescape.wiki/w/Black_chinchompa'}

# %% [markdown]
# So grey chinchompas and red chinchompas have `buy_limit==None`, but black chinchompas have a `buy_limit==11000`
#
# If I log into OSRS, I can check these values at the Grand Exchange or using a RuneLite plugin. Currently (Jan 06, 2021) grey and red chinchompas have a buy limit of 7,000 and black chinchompas have a buy limit of 11,000. We can also verify these same values on the Old School Runescape Wiki.
#
# So clearly, there is a problem with the buy limit on querying from `osrsbox-db` for these 2 items.

# %% [markdown]
# # Finding the Cause of the Problem #
#
# Calling `items_api.load()` in the above code creates an instance of `AllItems()`. If we search through the source code for the `AllItems()` class, we see that a dictionary with item properties is created as an attribute of the class (line 42 of `all_items.py`) using a particular JSON file called `items-complete.json`.
#
#
# Let's take a look at the entry for Chinchompas and Red chinchompas inside `items-complete.json`.
#
# *Note:  The unique Item ID for (grey) Chinchompas is 9976*

# %%
#github link to the raw file of `items-complete.json`
url = "https://raw.githubusercontent.com/osrsbox/osrsbox-db/master/osrsbox/docs/items-complete.json"
#this is `items-complete.json` as a Python dictionary
items_complete_dict = requests.get(url).json()

# %%
#get the value for chinchompas (id 9976)
#a glance at items-complete.json shows that keys are the item ids as strings
chinchompas_items_complete = items_complete_dict["9976"]
#select a few properties to look at
select = ["id", "name", "buy_limit", "wiki_url"]
{p:chinchompas_items_complete[p] for p in select}
# Out:
# {'id': 9976,
#  'name': 'Chinchompa',
#  'buy_limit': None,
#  'wiki_url': 'https://oldschool.runescape.wiki/w/Chinchompa'}

# %% [markdown]
# So the buy limits are incorrect because of the actual data inside `items-complete.json`.
#
# Looking further, we can see `item-buylimits.json` has a JSON object pairing "item name":buy_limit correctly! This file was created (correctly) by the `fetch()` method at `osrsbox-db/scripts/items/item_buylimits.py`.
#
# So let's see what other tradeables might have been affected, write a method to update `items-complete.json`, then test to see if the changes took place.

# %% [markdown]
# # Finding Other Affected Items #

# %%
item_buylimits_json = requests.get("https://raw.githubusercontent.com/osrsbox/osrsbox-db/master/data/items/items-buylimits.json").json()

affected_items = {}

for item in items_api.load().__iter__():
    if item.tradeable_on_ge:
        #use a the item ID to search the item in `items-complete.json`
        item_ID = str(item.id)
        #use the item name to search `items-buylimits.json`
        item_name = item.name
        try:
            #buy limit according to `items-complete.json`
            candidate_limit = items_complete_dict[item_ID]["buy_limit"]
            #buy limit according to `item_buylimits.json`
            truth_limit = item_buylimits_json[item_name]
        except KeyError:
            pass
        if candidate_limit != truth_limit:
            affected_items[item_name] = f"Candidate:{candidate_limit}  Truth:{truth_limit}"
affected_items
# Out:
# {'Priest gown': 'Candidate:150  Truth:11000',
#  'Shantay pass': 'Candidate:18000  Truth:150',
#  'Swamp toad': 'Candidate:13000  Truth:6000',
#  'Myre snelm': 'Candidate:150  Truth:11000',
#  "Blood'n'tar snelm": 'Candidate:150  Truth:11000',
#  'Ochre snelm': 'Candidate:150  Truth:11000',
#  'Bruise blue snelm': 'Candidate:150  Truth:11000',
#  'Blamish myre shell': 'Candidate:13000  Truth:150',
#  'Blamish red shell': 'Candidate:13000  Truth:150',
#  'Blamish ochre shell': 'Candidate:13000  Truth:150',
#  'Blamish blue shell': 'Candidate:13000  Truth:150',
#  'Candle lantern': 'Candidate:None  Truth:10000',
#  'Woven top': 'Candidate:150  Truth:4',
#  'Shirt': 'Candidate:150  Truth:4',
#  'Trousers': 'Candidate:150  Truth:4',
#  'Shorts': 'Candidate:150  Truth:4',
#  'Skirt': 'Candidate:150  Truth:4',
#  'Broodoo shield (10)': 'Candidate:None  Truth:11000',
#  'Broodoo shield': 'Candidate:None  Truth:11000',
#  'Tribal mask': 'Candidate:150  Truth:13000',
#  'Tribal top': 'Candidate:150  Truth:13000',
#  'Villager robe': 'Candidate:150  Truth:13000',
#  'Villager hat': 'Candidate:150  Truth:13000',
#  'Villager armband': 'Candidate:150  Truth:13000',
#  'Villager sandals': 'Candidate:150  Truth:13000',
#  'Sweetcorn': 'Candidate:13000  Truth:11000',
#  'Stripy pirate shirt': 'Candidate:150  Truth:11000',
#  'Pirate bandana': 'Candidate:150  Truth:11000',
#  'Snake hide': 'Candidate:11000  Truth:13000',
#  'Varrock teleport': 'Candidate:10000  Truth:13000',
#  'Lumbridge teleport': 'Candidate:10000  Truth:13000',
#  'Falador teleport': 'Candidate:10000  Truth:13000',
#  'Camelot teleport': 'Candidate:10000  Truth:13000',
#  'Ardougne teleport': 'Candidate:10000  Truth:13000',
#  'Watchtower teleport': 'Candidate:10000  Truth:13000',
#  'Teleport to house': 'Candidate:10000  Truth:13000',
#  'Bones to bananas': 'Candidate:10000  Truth:13000',
#  'Bones to peaches': 'Candidate:10000  Truth:13000',
#  'Crude chair': 'Candidate:500  Truth:10000',
#  'Wooden chair': 'Candidate:500  Truth:10000',
#  'Rocking chair': 'Candidate:500  Truth:10000',
#  'Oak chair': 'Candidate:500  Truth:10000',
#  'Oak armchair': 'Candidate:500  Truth:10000',
#  'Teak armchair': 'Candidate:500  Truth:10000',
#  'Mahogany armchair': 'Candidate:500  Truth:10000',
#  'Bookcase': 'Candidate:500  Truth:10000',
#  'Oak bookcase': 'Candidate:500  Truth:10000',
#  'Mahogany bookcase': 'Candidate:500  Truth:10000',
#  'Beer barrel': 'Candidate:500  Truth:10000',
#  'Cider barrel': 'Candidate:500  Truth:10000',
#  'Asgarnian ale': 'Candidate:500  Truth:2000',
#  "Greenman's ale": 'Candidate:500  Truth:2000',
#  'Dragon bitter': 'Candidate:500  Truth:2000',
#  "Chef's delight": 'Candidate:500  Truth:2000',
#  'Kitchen table': 'Candidate:500  Truth:2000',
#  'Oak kitchen table': 'Candidate:500  Truth:2000',
#  'Teak kitchen table': 'Candidate:500  Truth:2000',
#  'Wood dining table': 'Candidate:500  Truth:2000',
#  'Oak dining table': 'Candidate:500  Truth:2000',
#  'Carved oak table': 'Candidate:500  Truth:2000',
#  'Teak table': 'Candidate:500  Truth:2000',
#  'Carved teak table': 'Candidate:500  Truth:2000',
#  'Mahogany table': 'Candidate:500  Truth:2000',
#  'Opulent table': 'Candidate:500  Truth:2000',
#  'Wooden bench': 'Candidate:500  Truth:2000',
#  'Oak bench': 'Candidate:500  Truth:2000',
#  'Carved oak bench': 'Candidate:500  Truth:2000',
#  'Teak dining bench': 'Candidate:500  Truth:2000',
#  'Carved teak bench': 'Candidate:500  Truth:2000',
#  'Mahogany bench': 'Candidate:500  Truth:2000',
#  'Gilded bench': 'Candidate:500  Truth:2000',
#  'Wooden bed': 'Candidate:500  Truth:2000',
#  'Oak bed': 'Candidate:500  Truth:2000',
#  'Large oak bed': 'Candidate:500  Truth:2000',
#  'Teak bed': 'Candidate:500  Truth:2000',
#  'Large teak bed': 'Candidate:500  Truth:2000',
#  'Four-poster bed': 'Candidate:500  Truth:2000',
#  'Gilded four-poster': 'Candidate:500  Truth:2000',
#  'Oak clock': 'Candidate:500  Truth:2000',
#  'Teak clock': 'Candidate:500  Truth:2000',
#  'Gilded clock': 'Candidate:500  Truth:2000',
#  'Shaving stand': 'Candidate:500  Truth:2000',
#  'Oak shaving stand': 'Candidate:500  Truth:2000',
#  'Oak dresser': 'Candidate:500  Truth:2000',
#  'Teak dresser': 'Candidate:500  Truth:2000',
#  'Fancy teak dresser': 'Candidate:500  Truth:2000',
#  'Mahogany dresser': 'Candidate:500  Truth:2000',
#  'Gilded dresser': 'Candidate:500  Truth:2000',
#  'Shoe box': 'Candidate:500  Truth:2000',
#  'Oak drawers': 'Candidate:500  Truth:2000',
#  'Oak wardrobe': 'Candidate:500  Truth:2000',
#  'Teak drawers': 'Candidate:500  Truth:2000',
#  'Teak wardrobe': 'Candidate:500  Truth:2000',
#  'Mahogany wardrobe': 'Candidate:500  Truth:2000',
#  'Gilded wardrobe': 'Candidate:500  Truth:2000',
#  'Bandana eyepatch': 'Candidate:150  Truth:70',
#  'Oak cape rack': 'Candidate:500  Truth:2000',
#  'Teak cape rack': 'Candidate:500  Truth:2000',
#  'Mahogany cape rack': 'Candidate:500  Truth:2000',
#  'Gilded cape rack': 'Candidate:500  Truth:2000',
#  'Marble cape rack': 'Candidate:500  Truth:2000',
#  'Magic cape rack': 'Candidate:500  Truth:2000',
#  'Oak toy box': 'Candidate:500  Truth:2000',
#  'Teak toy box': 'Candidate:500  Truth:2000',
#  'Mahogany toy box': 'Candidate:500  Truth:2000',
#  'Oak magic wardrobe': 'Candidate:500  Truth:2000',
#  'Carved oak magic wardrobe': 'Candidate:500  Truth:2000',
#  'Teak magic wardrobe': 'Candidate:500  Truth:2000',
#  'Carved teak magic wardrobe': 'Candidate:500  Truth:2000',
#  'Mahogany magic wardrobe': 'Candidate:500  Truth:2000',
#  'Gilded magic wardrobe': 'Candidate:500  Truth:2000',
#  'Marble magic wardrobe': 'Candidate:500  Truth:2000',
#  'Oak armour case': 'Candidate:500  Truth:2000',
#  'Teak armour case': 'Candidate:500  Truth:2000',
#  'Mahogany armour case': 'Candidate:500  Truth:2000',
#  'Oak treasure chest': 'Candidate:500  Truth:2000',
#  'Teak treasure chest': 'Candidate:500  Truth:2000',
#  'M. treasure chest': 'Candidate:500  Truth:2000',
#  'Oak fancy dress box': 'Candidate:500  Truth:2000',
#  'Teak fancy dress box': 'Candidate:500  Truth:2000',
#  'Mahogany fancy dress box': 'Candidate:500  Truth:2000',
#  'Black warlock': 'Candidate:125  Truth:40',
#  'Snowy knight': 'Candidate:125  Truth:40',
#  'Sapphire glacialis': 'Candidate:125  Truth:40',
#  'Ruby harvest': 'Candidate:125  Truth:40',
#  'Yak-hide armour': 'Candidate:70  Truth:13000',
#  'Annakarl teleport': 'Candidate:10000  Truth:4',
#  'Carrallangar teleport': 'Candidate:10000  Truth:4',
#  'Dareeyak teleport': 'Candidate:10000  Truth:4',
#  'Ghorrock teleport': 'Candidate:10000  Truth:4',
#  'Kharyrll teleport': 'Candidate:10000  Truth:4',
#  'Lassar teleport': 'Candidate:10000  Truth:4',
#  'Paddewwa teleport': 'Candidate:10000  Truth:4',
#  'Senntisten teleport': 'Candidate:10000  Truth:4',
#  'Teleport card': 'Candidate:None  Truth:200',
#  'Lumbridge graveyard teleport': 'Candidate:10000  Truth:8',
#  'Draynor manor teleport': 'Candidate:10000  Truth:8',
#  'Mind altar teleport': 'Candidate:10000  Truth:8',
#  'Salve graveyard teleport': 'Candidate:10000  Truth:8',
#  "Fenkenstrain's castle teleport": 'Candidate:10000  Truth:8',
#  'West ardougne teleport': 'Candidate:10000  Truth:8',
#  'Harmony island teleport': 'Candidate:10000  Truth:8',
#  'Cemetery teleport': 'Candidate:10000  Truth:8',
#  'Barrows teleport': 'Candidate:10000  Truth:8',
#  'Ape atoll teleport': 'Candidate:10000  Truth:8',
#  'Battlefront teleport': 'Candidate:10000  Truth:12000',
#  'Dragonstone armour set': 'Candidate:None  Truth:70',
#  'Zalcano shard': 'Candidate:None  Truth:2000',
#  'Elven signet': 'Candidate:None  Truth:2000',
#  'Elven dawn': 'Candidate:None  Truth:2000',
#  'Crystal tool seed': 'Candidate:None  Truth:2000',
#  'Crystal armour seed': 'Candidate:None  Truth:2000',
#  'Enhanced crystal teleport seed': 'Candidate:None  Truth:2000',
#  'Blade of saeldor (inactive)': 'Candidate:None  Truth:2000',
#  'Crystal grail': 'Candidate:None  Truth:2000',
#  'Elven boots': 'Candidate:None  Truth:2000',
#  'Elven gloves': 'Candidate:None  Truth:2000',
#  'Elven top': 'Candidate:None  Truth:2000',
#  'Elven skirt': 'Candidate:None  Truth:2000',
#  'Elven legwear': 'Candidate:None  Truth:2000',
#  'Dragonstone full helm': 'Candidate:None  Truth:2000',
#  'Dragonstone platebody': 'Candidate:None  Truth:2000',
#  'Dragonstone platelegs': 'Candidate:None  Truth:2000',
#  'Dragonstone boots': 'Candidate:None  Truth:2000',
#  'Dragonstone gauntlets': 'Candidate:None  Truth:2000',
#  'Staff of balance': 'Candidate:None  Truth:2000',
#  'Trouver parchment': 'Candidate:None  Truth:2000',
#  'Swift blade': 'Candidate:None  Truth:2000',
#  'Wilderness crabs teleport': 'Candidate:None  Truth:50',
#  'Basilisk jaw': 'Candidate:None  Truth:50',
#  "Dagon'hai hat": 'Candidate:None  Truth:50',
#  "Dagon'hai robe top": 'Candidate:None  Truth:50',
#  "Dagon'hai robe bottom": 'Candidate:None  Truth:50',
#  "Dagon'hai robes set": 'Candidate:None  Truth:50',
#  'Target teleport': 'Candidate:None  Truth:50',
#  'Twisted hat (t3)': 'Candidate:None  Truth:50',
#  'Twisted coat (t3)': 'Candidate:None  Truth:50',
#  'Twisted trousers (t3)': 'Candidate:None  Truth:50',
#  'Twisted boots (t3)': 'Candidate:None  Truth:50',
#  'Twisted cane': 'Candidate:None  Truth:50',
#  'Twisted hat (t2)': 'Candidate:None  Truth:50',
#  'Twisted coat (t2)': 'Candidate:None  Truth:50',
#  'Twisted trousers (t2)': 'Candidate:None  Truth:50',
#  'Twisted boots (t2)': 'Candidate:None  Truth:50',
#  'Twisted hat (t1)': 'Candidate:None  Truth:50',
#  'Twisted coat (t1)': 'Candidate:None  Truth:50',
#  'Twisted trousers (t1)': 'Candidate:None  Truth:50',
#  'Twisted boots (t1)': 'Candidate:None  Truth:50',
#  'Twisted banner': 'Candidate:None  Truth:50',
#  "Inquisitor's mace": 'Candidate:None  Truth:50',
#  "Inquisitor's great helm": 'Candidate:None  Truth:50',
#  "Inquisitor's hauberk": 'Candidate:None  Truth:50',
#  "Inquisitor's plateskirt": 'Candidate:None  Truth:50',
#  'Nightmare staff': 'Candidate:None  Truth:50',
#  'Twisted teleport scroll': 'Candidate:None  Truth:50',
#  'Twisted blueprints': 'Candidate:None  Truth:50',
#  'Twisted relic hunter (t2) armour set': 'Candidate:None  Truth:5',
#  'Twisted relic hunter (t3) armour set': 'Candidate:None  Truth:5',
#  "Inquisitor's armour set": 'Candidate:None  Truth:5',
#  'Jar of dreams': 'Candidate:None  Truth:5',
#  'Harmonised orb': 'Candidate:None  Truth:5',
#  'Volatile orb': 'Candidate:None  Truth:5',
#  'Eldritch orb': 'Candidate:None  Truth:5',
#  'Rune pouch note': 'Candidate:None  Truth:40',
#  'Blighted anglerfish': 'Candidate:None  Truth:12000',
#  'Blighted karambwan': 'Candidate:None  Truth:12000',
#  'Blighted ancient ice sack': 'Candidate:None  Truth:2000',
#  'Blighted bind sack': 'Candidate:None  Truth:2000',
#  'Blighted snare sack': 'Candidate:None  Truth:2000',
#  'Blighted entangle sack': 'Candidate:None  Truth:2000',
#  'Blighted teleport spell sack': 'Candidate:None  Truth:2000',
#  'Blighted vengeance sack': 'Candidate:None  Truth:2000',
#  'Divine battlemage potion(4)': 'Candidate:None  Truth:2000',
#  'Divine battlemage potion(3)': 'Candidate:None  Truth:2000',
#  'Divine battlemage potion(2)': 'Candidate:None  Truth:2000',
#  'Divine battlemage potion(1)': 'Candidate:None  Truth:2000',
#  'Divine bastion potion(4)': 'Candidate:None  Truth:2000',
#  'Divine bastion potion(3)': 'Candidate:None  Truth:2000',
#  'Divine bastion potion(2)': 'Candidate:None  Truth:2000',
#  'Divine bastion potion(1)': 'Candidate:None  Truth:2000',
#  'Strange old lockpick (full)': 'Candidate:None  Truth:2000',
#  'Blood shard': 'Candidate:None  Truth:2000',
#  'Raw mystery meat': 'Candidate:None  Truth:2000',
#  'Cooked mystery meat': 'Candidate:None  Truth:2000',
#  'Ring of endurance (uncharged)': 'Candidate:None  Truth:2000',
#  'Moonclan teleport': 'Candidate:10000  Truth:2000',
#  'Ourania teleport': 'Candidate:10000  Truth:2000',
#  'Waterbirth teleport': 'Candidate:10000  Truth:2000',
#  'Barbarian teleport': 'Candidate:10000  Truth:2000',
#  'Khazard teleport': 'Candidate:10000  Truth:2000',
#  'Fishing guild teleport': 'Candidate:10000  Truth:2000',
#  'Catherby teleport': 'Candidate:10000  Truth:2000',
#  'Ice plateau teleport': 'Candidate:10000  Truth:2000',
#  'Trailblazer hood (t3)': 'Candidate:None  Truth:2000',
#  'Trailblazer coat (t3)': 'Candidate:None  Truth:2000',
#  'Trailblazer trousers (t3)': 'Candidate:None  Truth:2000',
#  'Trailblazer boots (t3)': 'Candidate:None  Truth:2000',
#  'Trailblazer cane': 'Candidate:None  Truth:2000',
#  'Trailblazer hood (t2)': 'Candidate:None  Truth:2000',
#  'Trailblazer coat (t2)': 'Candidate:None  Truth:2000',
#  'Trailblazer trousers (t2)': 'Candidate:None  Truth:2000',
#  'Trailblazer boots (t2)': 'Candidate:None  Truth:2000',
#  'Trailblazer hood (t1)': 'Candidate:None  Truth:2000',
#  'Trailblazer coat (t1)': 'Candidate:None  Truth:2000',
#  'Trailblazer trousers (t1)': 'Candidate:None  Truth:2000',
#  'Trailblazer boots (t1)': 'Candidate:None  Truth:2000',
#  'Trailblazer banner': 'Candidate:None  Truth:2000',
#  'Trailblazer harpoon': 'Candidate:None  Truth:2000',
#  'Trailblazer pickaxe': 'Candidate:None  Truth:2000',
#  'Trailblazer axe': 'Candidate:None  Truth:2000',
#  'Trailblazer teleport scroll': 'Candidate:None  Truth:2000',
#  'Trailblazer tool ornament kit': 'Candidate:None  Truth:2000',
#  'Trailblazer globe': 'Candidate:None  Truth:2000',
#  'Trailblazer rug': 'Candidate:None  Truth:2000',
#  'Trailblazer graceful ornament kit': 'Candidate:None  Truth:2000'}

# %% [markdown]
#  # Our Investigation Shows a New Problem! #
#
# The above shows that some of our assumptions were incorrect. Take a look at "Lumbridge Teleport", for example...

# %%
affected_items["Lumbridge teleport"]
# Out:
# 'Candidate:10000  Truth:13000'

# %% [markdown]
# This line is saying that the Lumbridge teleport buy limit *should* be set to 13,000, but we currently have it set to 10,000.
#
# However, if we visit [the OSRS Wiki page](https://oldschool.runescape.wiki/w/Lumbridge_teleport_(tablet)) for this item, we clearly see that **the actual buy limit is 10,000**. Logging into the game confirms that 10,000 is the true buy limit, too.
#
# So, our initial thoughts that it was a mismatch in the JSON files was somewhat correct - there *is* a mismatch - however, where a single file is not responsible for the mismatch.

# %% [markdown]
# # Our New Solution #
#
# The Old School Wiki has proven throughout this investigation to be reliable, matching with in-game limits at every check.
#
# So, my proposed solution is to build a web scraper to get buy limits from the OSRS Wiki. Then, we can update the corresponding JSON files in the project repository with our scraper values. Finally, we can test our solution using the items we looked at above.

# %% [markdown]
# # OSRS Wiki Scraper #

# %%
#tabular contents of the page
osrswiki = requests.get("https://oldschool.runescape.wiki/w/Grand_Exchange/Buying_limits").text
#pandas DataFrame of the buy limits table
contents = pd.DataFrame(pd.read_html(osrswiki)[0])
contents
# Out:
#                        Item  Buy limit
# 0            3rd age amulet          8
# 1               3rd age axe         40
# 2               3rd age bow          8
# 3             3rd age cloak          8
# 4     3rd age druidic cloak          8
# ...                     ...        ...
# 3579            Zogre bones       3000
# 3580            Zombie head          4
# 3581     Zul-andra teleport      10000
# 3582        Zulrah's scales      30000
# 3583         Zuriel's staff         10
#
# [3584 rows x 2 columns]

# %%
#items we looked at and noticed had problems
known_wrong_items = ["Chinchompa", "Red chinchompa", "Black chinchompa", "Lumbridge teleport"]
#quick visual check that with our scraper the buy limits are correct
[(r, contents[contents["Item"]==r]["Buy limit"].to_numpy()[0]) for r in known_wrong_items]
# Out:
# [('Chinchompa', 7000),
#  ('Red chinchompa', 7000),
#  ('Black chinchompa', 11000),
#  ('Lumbridge teleport', 10000)]

# %%
contents["Item"]
# Out:
# 0              3rd age amulet
# 1                 3rd age axe
# 2                 3rd age bow
# 3               3rd age cloak
# 4       3rd age druidic cloak
#                 ...
# 3579              Zogre bones
# 3580              Zombie head
# 3581       Zul-andra teleport
# 3582          Zulrah's scales
# 3583           Zuriel's staff
# Name: Item, Length: 3584, dtype: object

# %%
foo = contents.to_dict(orient="dict")
foo
# Out:
# {'Item': {0: '3rd age amulet',
#   1: '3rd age axe',
#   2: '3rd age bow',
#   3: '3rd age cloak',
#   4: '3rd age druidic cloak',
#   5: '3rd age druidic robe bottoms',
#   6: '3rd age druidic robe top',
#   7: '3rd age druidic staff',
#   8: '3rd age full helmet',
#   9: '3rd age kiteshield',
#   10: '3rd age longsword',
#   11: '3rd age mage hat',
#   12: '3rd age pickaxe',
#   13: '3rd age platebody',
#   14: '3rd age platelegs',
#   15: '3rd age plateskirt',
#   16: '3rd age range coif',
#   17: '3rd age range legs',
#   18: '3rd age range top',
#   19: '3rd age robe top',
#   20: '3rd age robe',
#   21: '3rd age vambraces',
#   22: '3rd age wand',
#   23: 'A powdered wig',
#   24: 'Abyssal bludgeon',
#   25: 'Abyssal bracelet(5)',
#   26: 'Abyssal dagger (p)',
#   27: 'Abyssal dagger (p+)',
#   28: 'Abyssal dagger (p++)',
#   29: 'Abyssal dagger',
#   30: 'Abyssal whip',
#   31: 'Achey tree logs',
#   32: 'Acorn',
#   33: 'Adamant 2h sword',
#   34: 'Adamant arrow(p)',
#   35: 'Adamant arrow(p+)',
#   36: 'Adamant arrow(p++)',
#   37: 'Adamant arrow',
#   38: 'Adamant arrowtips',
#   39: 'Adamant axe',
#   40: 'Adamant battleaxe',
#   41: 'Adamant bolts (p)',
#   42: 'Adamant bolts (p+)',
#   43: 'Adamant bolts (p++)',
#   44: 'Adamant bolts(unf)',
#   45: 'Adamant bolts',
#   46: 'Adamant boots',
#   47: 'Adamant brutal',
#   48: 'Adamant cane',
#   49: 'Adamant chainbody',
#   50: 'Adamant claws',
#   51: 'Adamant crossbow (u)',
#   52: 'Adamant crossbow',
#   53: 'Adamant dagger(p)',
#   54: 'Adamant dagger(p+)',
#   55: 'Adamant dagger(p++)',
#   56: 'Adamant dagger',
#   57: 'Adamant dart tip',
#   58: 'Adamant dart(p)',
#   59: 'Adamant dart(p+)',
#   60: 'Adamant dart(p++)',
#   61: 'Adamant dart',
#   62: 'Adamant dragon mask',
#   63: 'Adamant full helm (g)',
#   64: 'Adamant full helm (t)',
#   65: 'Adamant full helm',
#   66: 'Adamant gold-trimmed set (lg)',
#   67: 'Adamant gold-trimmed set (sk)',
#   68: 'Adamant halberd',
#   69: 'Adamant hasta(p)',
#   70: 'Adamant hasta(p+)',
#   71: 'Adamant hasta(p++)',
#   72: 'Adamant hasta',
#   73: 'Adamant helm (h1)',
#   74: 'Adamant helm (h2)',
#   75: 'Adamant helm (h3)',
#   76: 'Adamant helm (h4)',
#   77: 'Adamant helm (h5)',
#   78: 'Adamant javelin heads',
#   79: 'Adamant javelin(p)',
#   80: 'Adamant javelin(p+)',
#   81: 'Adamant javelin(p++)',
#   82: 'Adamant javelin',
#   83: 'Adamant kiteshield (g)',
#   84: 'Adamant kiteshield (t)',
#   85: 'Adamant kiteshield',
#   86: 'Adamant knife(p)',
#   87: 'Adamant knife(p+)',
#   88: 'Adamant knife(p++)',
#   89: 'Adamant knife',
#   90: 'Adamant longsword',
#   91: 'Adamant mace',
#   92: 'Adamant med helm',
#   93: 'Adamant pickaxe',
#   94: 'Adamant platebody (g)',
#   95: 'Adamant platebody (h1)',
#   96: 'Adamant platebody (h2)',
#   97: 'Adamant platebody (h3)',
#   98: 'Adamant platebody (h4)',
#   99: 'Adamant platebody (h5)',
#   100: 'Adamant platebody (t)',
#   101: 'Adamant platebody',
#   102: 'Adamant platelegs (g)',
#   103: 'Adamant platelegs (t)',
#   104: 'Adamant platelegs',
#   105: 'Adamant plateskirt (g)',
#   106: 'Adamant plateskirt (t)',
#   107: 'Adamant plateskirt',
#   108: 'Adamant scimitar',
#   109: 'Adamant set (lg)',
#   110: 'Adamant set (sk)',
#   111: 'Adamant shield (h1)',
#   112: 'Adamant shield (h2)',
#   113: 'Adamant shield (h3)',
#   114: 'Adamant shield (h4)',
#   115: 'Adamant shield (h5)',
#   116: 'Adamant spear(p)',
#   117: 'Adamant spear(p+)',
#   118: 'Adamant spear(p++)',
#   119: 'Adamant spear',
#   120: 'Adamant sq shield',
#   121: 'Adamant sword',
#   122: 'Adamant thrownaxe',
#   123: 'Adamant trimmed set (lg)',
#   124: 'Adamant trimmed set (sk)',
#   125: 'Adamant warhammer',
#   126: 'Adamantite bar',
#   127: 'Adamantite limbs',
#   128: 'Adamantite nails',
#   129: 'Adamantite ore',
#   130: 'Admiral pie',
#   131: 'Afro',
#   132: 'Agility mix(1)',
#   133: 'Agility mix(2)',
#   134: 'Agility potion(1)',
#   135: 'Agility potion(2)',
#   136: 'Agility potion(3)',
#   137: 'Agility potion(4)',
#   138: "Ahrim's armour set",
#   139: "Ahrim's hood 0",
#   140: "Ahrim's hood",
#   141: "Ahrim's robeskirt 0",
#   142: "Ahrim's robeskirt",
#   143: "Ahrim's robetop 0",
#   144: "Ahrim's robetop",
#   145: "Ahrim's staff 0",
#   146: "Ahrim's staff",
#   147: 'Air battlestaff',
#   148: 'Air orb',
#   149: 'Air rune',
#   150: 'Air tiara',
#   151: 'Air talisman',
#   152: 'Airtight pot',
#   153: 'Ale of the gods',
#   154: 'Ale yeast',
#   155: 'Amethyst arrow(p)',
#   156: 'Amethyst arrow(p+)',
#   157: 'Amethyst arrow(p++)',
#   158: 'Amethyst arrow',
#   159: 'Amethyst arrowtips',
#   160: 'Amethyst bolt tips',
#   161: 'Amethyst broad bolts',
#   162: 'Amethyst javelin heads',
#   163: 'Amethyst javelin(p)',
#   164: 'Amethyst javelin(p+)',
#   165: 'Amethyst javelin(p++)',
#   166: 'Amethyst javelin',
#   167: 'Amethyst',
#   168: 'Amulet mould',
#   169: 'Amulet of accuracy',
#   170: 'Amulet of avarice',
#   171: 'Amulet of bounty',
#   172: 'Amulet of chemistry',
#   173: 'Amulet of defence (t)',
#   174: 'Amulet of defence',
#   175: 'Amulet of eternal glory',
#   176: 'Amulet of fury',
#   177: 'Amulet of glory (t)',
#   178: 'Amulet of glory (t4)',
#   179: 'Amulet of glory (t6)',
#   180: 'Amulet of glory(4)',
#   181: 'Amulet of glory(6)',
#   182: 'Amulet of glory',
#   183: 'Amulet of magic (t)',
#   184: 'Amulet of magic',
#   185: 'Amulet of power (t)',
#   186: 'Amulet of power',
#   187: 'Amulet of strength',
#   188: 'Amulet of the damned (full)',
#   189: 'Amulet of torture',
#   190: 'Amylase crystal',
#   191: 'Ancestral hat',
#   192: 'Ancestral robe bottom',
#   193: 'Ancestral robe top',
#   194: 'Ancestral robes set',
#   195: 'Anchovies',
#   196: 'Anchovy pizza',
#   197: 'Ancient blessing',
#   198: 'Ancient bracers',
#   199: 'Ancient chaps',
#   200: 'Ancient cloak',
#   201: 'Ancient coif',
#   202: 'Ancient crozier',
#   203: 'Ancient crystal',
#   204: "Ancient d'hide boots",
#   205: "Ancient d'hide shield",
#   206: "Ancient d'hide body",
#   207: 'Ancient dragonhide set',
#   208: 'Ancient effigy',
#   209: 'Ancient emblem',
#   210: 'Ancient full helm',
#   211: 'Ancient kiteshield',
#   212: 'Ancient mace',
#   213: 'Ancient medallion',
#   214: 'Ancient mitre',
#   215: 'Ancient page 1',
#   216: 'Ancient page 2',
#   217: 'Ancient page 3',
#   218: 'Ancient page 4',
#   219: 'Ancient platebody',
#   220: 'Ancient platelegs',
#   221: 'Ancient plateskirt',
#   222: 'Ancient relic',
#   223: 'Ancient robe legs',
#   224: 'Ancient robe top',
#   225: 'Ancient rune armour set (lg)',
#   226: 'Ancient rune armour set (sk)',
#   227: 'Ancient staff',
#   228: 'Ancient statuette',
#   229: 'Ancient stole',
#   230: 'Ancient totem',
#   231: 'Ancient wyvern shield',
#   232: 'Anglerfish',
#   233: 'Anguish ornament kit',
#   234: 'Ankou gloves',
#   235: "Ankou's leggings",
#   236: 'Ankou mask',
#   237: 'Ankou socks',
#   238: 'Ankou top',
#   239: 'Annakarl teleport',
#   240: 'Anti-dragon shield',
#   241: 'Anti-poison supermix(1)',
#   242: 'Anti-poison supermix(2)',
#   243: 'Anti-venom(1)',
#   244: 'Anti-venom(2)',
#   245: 'Anti-venom(3)',
#   246: 'Anti-venom(4)',
#   247: 'Anti-venom+(1)',
#   248: 'Anti-venom+(2)',
#   249: 'Anti-venom+(3)',
#   250: 'Anti-venom+(4)',
#   251: 'Antidote+ mix(1)',
#   252: 'Antidote+ mix(2)',
#   253: 'Antidote+(1)',
#   254: 'Antidote+(2)',
#   255: 'Antidote+(3)',
#   256: 'Antidote+(4)',
#   257: 'Antidote++(1)',
#   258: 'Antidote++(2)',
#   259: 'Antidote++(3)',
#   260: 'Antidote++(4)',
#   261: 'Antifire mix(1)',
#   262: 'Antifire mix(2)',
#   263: 'Antifire potion(1)',
#   264: 'Antifire potion(2)',
#   265: 'Antifire potion(3)',
#   266: 'Antifire potion(4)',
#   267: 'Antipoison mix(1)',
#   268: 'Antipoison mix(2)',
#   269: 'Antipoison(1)',
#   270: 'Antipoison(2)',
#   271: 'Antipoison(3)',
#   272: 'Antipoison(4)',
#   273: 'Ape atoll teleport',
#   274: 'Apple mush',
#   275: 'Apple pie',
#   276: 'Apple sapling',
#   277: 'Apple tree seed',
#   278: 'Apples(5)',
#   279: 'Apprentice wand',
#   280: 'Arcane prayer scroll',
#   281: 'Arcane sigil',
#   282: 'Arcane spirit shield',
#   283: 'Arceuus banner',
#   284: 'Arceuus hood',
#   285: 'Arceuus scarf',
#   286: 'Archer helm',
#   287: 'Archers ring',
#   288: 'Archery ticket',
#   289: 'Arctic pine logs',
#   290: 'Arctic pyre logs',
#   291: 'Ardougne teleport',
#   292: 'Arena book',
#   293: 'Armadyl bracers',
#   294: 'Armadyl chainskirt',
#   295: 'Armadyl chaps',
#   296: 'Armadyl chestplate',
#   297: 'Armadyl cloak',
#   298: 'Armadyl coif',
#   299: 'Armadyl crossbow',
#   300: 'Armadyl crozier',
#   301: "Armadyl d'hide boots",
#   302: "Armadyl d'hide shield",
#   303: "Armadyl d'hide body",
#   304: 'Armadyl dragonhide set',
#   305: 'Armadyl full helm',
#   306: 'Armadyl godsword ornament kit',
#   307: 'Armadyl godsword',
#   308: 'Armadyl helmet',
#   309: 'Armadyl hilt',
#   310: 'Armadyl kiteshield',
#   311: 'Armadyl mitre',
#   312: 'Armadyl page 1',
#   313: 'Armadyl page 2',
#   314: 'Armadyl page 3',
#   315: 'Armadyl page 4',
#   316: 'Armadyl platebody',
#   317: 'Armadyl platelegs',
#   318: 'Armadyl plateskirt',
#   319: 'Armadyl robe legs',
#   320: 'Armadyl robe top',
#   321: 'Armadyl rune armour set (lg)',
#   322: 'Armadyl rune armour set (sk)',
#   323: 'Armadyl stole',
#   324: 'Arrow shaft',
#   325: 'Asgarnian ale(4)',
#   326: 'Asgarnian ale(m)',
#   327: 'Asgarnian ale(m4)',
#   328: 'Asgarnian ale',
#   329: 'Asgarnian ale',
#   330: 'Asgarnian hops',
#   331: 'Asgarnian seed',
#   332: 'Ashes',
#   333: 'Assorted flowers',
#   334: 'Astral rune',
#   335: 'Asyn remains',
#   336: 'Attack mix(1)',
#   337: 'Attack mix(2)',
#   338: 'Attack potion(1)',
#   339: 'Attack potion(2)',
#   340: 'Attack potion(3)',
#   341: 'Attack potion(4)',
#   342: 'Avantoe potion (unf)',
#   343: 'Avantoe seed',
#   344: 'Avantoe',
#   345: 'Avernic defender hilt',
#   346: "Axeman's folly(4)",
#   347: "Axeman's folly(m)",
#   348: "Axeman's folly(m4)",
#   349: "Axeman's folly",
#   350: 'Baby impling jar',
#   351: 'Babydragon bones',
#   352: 'Bag of salt',
#   353: 'Bagged bluebells',
#   354: 'Bagged daffodils',
#   355: 'Bagged dead tree',
#   356: 'Bagged flower',
#   357: 'Bagged magic tree',
#   358: 'Bagged maple tree',
#   359: 'Bagged marigolds',
#   360: 'Bagged nice tree',
#   361: 'Bagged oak tree',
#   362: 'Bagged plant 1',
#   363: 'Bagged plant 2',
#   364: 'Bagged plant 3',
#   365: 'Bagged roses',
#   366: 'Bagged sunflower',
#   367: 'Bagged willow tree',
#   368: 'Bagged yew tree',
#   369: 'Baked potato',
#   370: 'Ball of wool',
#   371: 'Ballista limbs',
#   372: 'Ballista spring',
#   373: 'Banana sapling',
#   374: 'Banana stew',
#   375: 'Banana tree seed',
#   376: 'Banana',
#   377: 'Bananas(5)',
#   378: 'Bandana eyepatch',
#   379: "Bandit's brew",
#   380: 'Bandos boots',
#   381: 'Bandos bracers',
#   382: 'Bandos chaps',
#   383: 'Bandos chestplate',
#   384: 'Bandos cloak',
#   385: 'Bandos coif',
#   386: 'Bandos crozier',
#   387: "Bandos d'hide boots",
#   388: "Bandos d'hide shield",
#   389: "Bandos d'hide body",
#   390: 'Bandos dragonhide set',
#   391: 'Bandos full helm',
#   392: 'Bandos godsword ornament kit',
#   393: 'Bandos godsword',
#   394: 'Bandos hilt',
#   395: 'Bandos kiteshield',
#   396: 'Bandos mitre',
#   397: 'Bandos page 1',
#   398: 'Bandos page 2',
#   399: 'Bandos page 3',
#   400: 'Bandos page 4',
#   401: 'Bandos platebody',
#   402: 'Bandos platelegs',
#   403: 'Bandos plateskirt',
#   404: 'Bandos robe legs',
#   405: 'Bandos robe top',
#   406: 'Bandos rune armour set (lg)',
#   407: 'Bandos rune armour set (sk)',
#   408: 'Bandos stole',
#   409: 'Bandos tassets',
#   410: 'Barb bolttips',
#   411: 'Barb-tail harpoon',
#   412: 'Barbarian teleport',
#   413: 'Barbed bolts',
#   414: 'Bark',
#   415: 'Barley malt',
#   416: 'Barley seed',
#   417: 'Barley',
#   418: 'Barrel',
#   419: 'Barrows teleport',
#   420: 'Basalt',
#   421: 'Basilisk jaw',
#   422: 'Basket',
#   423: 'Bass',
#   424: 'Bastion potion(1)',
#   425: 'Bastion potion(2)',
#   426: 'Bastion potion(3)',
#   427: 'Bastion potion(4)',
#   428: 'Bat bones',
#   429: 'Batta tin',
#   430: 'Battlefront teleport',
#   431: 'Battlemage potion(1)',
#   432: 'Battlemage potion(2)',
#   433: 'Battlemage potion(3)',
#   434: 'Battlemage potion(4)',
#   435: 'Battlestaff',
#   436: 'Beanie',
#   437: 'Bear feet',
#   438: 'Bear fur',
#   439: 'Beer barrel',
#   440: 'Beer glass',
#   441: 'Beer tankard',
#   442: 'Beer',
#   443: 'Beginner wand',
#   444: 'Belladonna seed',
#   445: 'Berserker helm',
#   446: 'Berserker necklace ornament kit',
#   447: 'Berserker necklace',
#   448: 'Berserker ring',
#   449: 'Big bones',
#   450: 'Big fishing net',
#   451: 'Big pirate hat',
#   452: 'Binding necklace',
#   453: 'Bird house',
#   454: 'Bird nest',
#   455: 'Bird snare',
#   456: 'Black 2h sword',
#   457: 'Black axe',
#   458: 'Black battleaxe',
#   459: 'Black bead',
#   460: 'Black beret',
#   461: 'Black boater',
#   462: 'Black boots',
#   463: 'Black brutal',
#   464: 'Black cane',
#   465: 'Black cape',
#   466: 'Black cavalier',
#   467: 'Black chainbody',
#   468: 'Black chinchompa',
#   469: 'Black claws',
#   470: "Black d'hide body (g)",
#   471: "Black d'hide body (t)",
#   472: "Black d'hide body",
#   473: "Black d'hide chaps (g)",
#   474: "Black d'hide chaps (t)",
#   475: "Black d'hide chaps",
#   476: "Black d'hide shield",
#   477: "Black d'hide vambraces",
#   478: 'Black dagger(p)',
#   479: 'Black dagger(p+)',
#   480: 'Black dagger(p++)',
#   481: 'Black dagger',
#   482: 'Black dart(p)',
#   483: 'Black dart(p+)',
#   484: 'Black dart(p++)',
#   485: 'Black dart',
#   486: 'Black demon mask',
#   487: 'Black desert robe',
#   488: 'Black desert shirt',
#   489: 'Black dragon leather',
#   490: 'Black dragon mask',
#   491: 'Black dragonhide set',
#   492: 'Black dragonhide',
#   493: 'Black elegant legs',
#   494: 'Black elegant shirt',
#   495: 'Black flowers',
#   496: 'Black full helm (g)',
#   497: 'Black full helm (t)',
#   498: 'Black full helm',
#   499: 'Black gold-trimmed set (lg)',
#   500: 'Black gold-trimmed set (sk)',
#   501: 'Black halberd',
#   502: 'Black headband',
#   503: 'Black helm (h1)',
#   504: 'Black helm (h2)',
#   505: 'Black helm (h3)',
#   506: 'Black helm (h4)',
#   507: 'Black helm (h5)',
#   508: 'Black kiteshield (g)',
#   509: 'Black kiteshield (t)',
#   510: 'Black kiteshield',
#   511: 'Black knife(p)',
#   512: 'Black knife(p+)',
#   513: 'Black knife(p++)',
#   514: 'Black knife',
#   515: 'Black leprechaun hat',
#   516: 'Black longsword',
#   517: 'Black mace',
#   518: 'Black mask (10)',
#   519: 'Black mask',
#   520: 'Black med helm',
#   521: 'Black nails',
#   522: 'Black pickaxe',
#   523: 'Black platebody (g)',
#   524: 'Black platebody (h1)',
#   525: 'Black platebody (h2)',
#   526: 'Black platebody (h3)',
#   527: 'Black platebody (h4)',
#   528: 'Black platebody (h5)',
#   529: 'Black platebody (t)',
#   530: 'Black platebody',
#   531: 'Black platelegs (g)',
#   532: 'Black platelegs (t)',
#   533: 'Black platelegs',
#   534: 'Black plateskirt (g)',
#   535: 'Black plateskirt (t)',
#   536: 'Black plateskirt',
#   537: 'Black robe',
#   538: 'Black salamander',
#   539: 'Black scimitar',
#   540: 'Black set (lg)',
#   541: 'Black set (sk)',
#   542: 'Black shield (h1)',
#   543: 'Black shield (h2)',
#   544: 'Black shield (h3)',
#   545: 'Black shield (h4)',
#   546: 'Black shield (h5)',
#   547: 'Black skirt (g)',
#   548: 'Black skirt (t)',
#   549: 'Black skirt',
#   550: 'Black spear(p)',
#   551: 'Black spear(p+)',
#   552: 'Black spear(p++)',
#   553: 'Black spear',
#   554: 'Black spiky vambraces',
#   555: 'Black sq shield',
#   556: 'Black sword',
#   557: 'Black tourmaline core',
#   558: 'Black toy horsey',
#   559: 'Black trimmed set (lg)',
#   560: 'Black trimmed set (sk)',
#   561: 'Black unicorn mask',
#   562: 'Black warhammer',
#   563: 'Black warlock',
#   564: 'Black wizard hat (g)',
#   565: 'Black wizard hat (t)',
#   566: 'Black wizard robe (g)',
#   567: 'Black wizard robe (t)',
#   568: "Blacksmith's helm",
#   569: 'Blamish bark shell',
#   570: 'Blamish blue shell',
#   571: 'Blamish myre shell',
#   572: 'Blamish ochre shell',
#   573: 'Blamish red shell',
#   574: 'Blessed spirit shield',
#   575: 'Blood rune',
#   576: "Blood'n'tar snelm",
#   577: 'Bloody bracer',
#   578: 'Blue beret',
#   579: 'Blue boater',
#   580: 'Blue boots',
#   581: 'Blue cape',
#   582: "Blue d'hide body (g)",
#   583: "Blue d'hide body (t)",
#   584: "Blue d'hide body",
#   585: "Blue d'hide chaps (g)",
#   586: "Blue d'hide chaps (t)",
#   587: "Blue d'hide chaps",
#   588: "Blue d'hide shield",
#   589: "Blue d'hide vambraces",
#   590: 'Blue dark bow paint',
#   591: 'Blue dragon leather',
#   592: 'Blue dragon mask',
#   593: 'Blue dragon scale',
#   594: 'Blue dragonhide set',
#   595: 'Blue dragonhide',
#   596: 'Blue dye',
#   597: 'Blue elegant blouse',
#   598: 'Blue elegant legs',
#   599: 'Blue elegant shirt',
#   600: 'Blue elegant skirt',
#   601: 'Blue feather',
#   602: 'Blue firelighter',
#   603: 'Blue flowers',
#   604: 'Blue halloween mask',
#   605: 'Blue hat',
#   606: 'Blue headband',
#   607: 'Blue partyhat',
#   608: 'Blue robe bottoms',
#   609: 'Blue robe top',
#   610: 'Blue skirt (g)',
#   611: 'Blue skirt (t)',
#   612: 'Blue skirt',
#   613: 'Blue spiky vambraces',
#   614: 'Blue wizard hat (g)',
#   615: 'Blue wizard hat (t)',
#   616: 'Blue wizard hat',
#   617: 'Blue wizard robe (g)',
#   618: 'Blue wizard robe (t)',
#   619: 'Blue wizard robe',
#   620: 'Bluegill',
#   621: 'Blurberry special',
#   622: "Bob's black shirt",
#   623: "Bob's blue shirt",
#   624: "Bob's green shirt",
#   625: "Bob's purple shirt",
#   626: "Bob's red shirt",
#   627: 'Body rune',
#   628: 'Body talisman',
#   629: 'Body tiara',
#   630: 'Bolt mould',
#   631: 'Bolt of cloth',
#   632: 'Bolt rack',
#   633: 'Bone bolts',
#   634: 'Bone club',
#   635: 'Bone dagger (p)',
#   636: 'Bone dagger (p+)',
#   637: 'Bone dagger (p++)',
#   638: 'Bone dagger',
#   639: 'Bone spear',
#   640: 'Bones to bananas',
#   641: 'Bones to peaches',
#   642: 'Bones',
#   643: 'Book of balance page set',
#   644: 'Book of darkness page set',
#   645: 'Book of law page set',
#   646: 'Book of war page set',
#   647: 'Bookcase',
#   648: 'Boots of darkness',
#   649: 'Boots of brimstone',
#   650: 'Boots of stone',
#   651: 'Botanical pie',
#   652: 'Bottle of wine',
#   653: 'Bottled dragonbreath (unpowered)',
#   654: 'Bottled dragonbreath',
#   655: 'Bottomless compost bucket',
#   656: 'Target teleport scroll',
#   657: 'Bow string',
#   658: 'Bowl of hot water',
#   659: 'Bowl of water',
#   660: 'Bowl wig',
#   661: 'Bowl',
#   662: 'Box trap',
#   663: 'Bracelet mould',
#   664: 'Bracelet of clay',
#   665: 'Bracelet of ethereum (uncharged)',
#   666: 'Bracelet of slaughter',
#   667: 'Brandy',
#   668: 'Brass necklace',
#   669: 'Brass key',
#   670: 'Bread dough',
#   671: 'Bread',
#   672: 'Briefcase',
#   673: 'Brimstone ring',
#   674: 'Brine sabre',
#   675: 'Broad arrowheads',
#   676: 'Broad bolts',
#   677: 'Broken bark snelm',
#   678: 'Broken dragon hasta',
#   679: 'Bronze 2h sword',
#   680: 'Bronze arrow(p)',
#   681: 'Bronze arrow(p+)',
#   682: 'Bronze arrow(p++)',
#   683: 'Bronze arrow',
#   684: 'Bronze arrowtips',
#   685: 'Bronze axe',
#   686: 'Bronze bar',
#   687: 'Bronze battleaxe',
#   688: 'Bronze bolts (p)',
#   689: 'Bronze bolts (p+)',
#   690: 'Bronze bolts (p++)',
#   691: 'Bronze bolts (unf)',
#   692: 'Bronze bolts',
#   693: 'Bronze boots',
#   694: 'Bronze brutal',
#   695: 'Bronze chainbody',
#   696: 'Bronze claws',
#   697: 'Bronze crossbow (u)',
#   698: 'Bronze crossbow',
#   699: 'Bronze dagger(p)',
#   700: 'Bronze dagger(p+)',
#   701: 'Bronze dagger(p++)',
#   702: 'Bronze dagger',
#   703: 'Bronze dart tip',
#   704: 'Bronze dart(p)',
#   705: 'Bronze dart(p+)',
#   706: 'Bronze dart(p++)',
#   707: 'Bronze dart',
#   708: 'Bronze dragon mask',
#   709: 'Bronze full helm (g)',
#   710: 'Bronze full helm (t)',
#   711: 'Bronze full helm',
#   712: 'Bronze gold-trimmed set (lg)',
#   713: 'Bronze gold-trimmed set (sk)',
#   714: 'Bronze halberd',
#   715: 'Bronze hasta(p)',
#   716: 'Bronze hasta(p+)',
#   717: 'Bronze hasta(p++)',
#   718: 'Bronze hasta',
#   719: 'Bronze javelin heads',
#   720: 'Bronze javelin(p)',
#   721: 'Bronze javelin(p+)',
#   722: 'Bronze javelin(p++)',
#   723: 'Bronze javelin',
#   724: 'Bronze kiteshield (g)',
#   725: 'Bronze kiteshield (t)',
#   726: 'Bronze kiteshield',
#   727: 'Bronze knife(p)',
#   728: 'Bronze knife(p+)',
#   729: 'Bronze knife(p++)',
#   730: 'Bronze knife',
#   731: 'Bronze limbs',
#   732: 'Bronze longsword',
#   733: 'Bronze mace',
#   734: 'Bronze med helm',
#   735: 'Bronze nails',
#   736: 'Bronze pickaxe',
#   737: 'Bronze platebody (g)',
#   738: 'Bronze platebody (t)',
#   739: 'Bronze platebody',
#   740: 'Bronze platelegs (g)',
#   741: 'Bronze platelegs (t)',
#   742: 'Bronze platelegs',
#   743: 'Bronze plateskirt (g)',
#   744: 'Bronze plateskirt (t)',
#   745: 'Bronze plateskirt',
#   746: 'Bronze scimitar',
#   747: 'Bronze set (lg)',
#   748: 'Bronze set (sk)',
#   749: 'Bronze spear(p)',
#   750: 'Bronze spear(p+)',
#   751: 'Bronze spear(p++)',
#   752: 'Bronze spear',
#   753: 'Bronze sq shield',
#   754: 'Bronze sword',
#   755: 'Bronze thrownaxe',
#   756: 'Bronze trimmed set (lg)',
#   757: 'Bronze trimmed set (sk)',
#   758: 'Bronze warhammer',
#   759: 'Bronze wire',
#   760: 'Broodoo shield (10)',
#   761: 'Broodoo shield',
#   762: 'Brown apron',
#   763: 'Brown headband',
#   764: 'Brown toy horsey',
#   765: 'Bruise blue snelm',
#   766: "Bryophyta's essence",
#   767: "Bryophyta's staff (uncharged)",
#   768: "Bryophyta's staff",
#   769: 'Bucket helm (g)',
#   770: 'Bucket helm',
#   771: 'Bucket of milk',
#   772: 'Bucket of sand',
#   773: 'Bucket of sap',
#   774: 'Bucket of water',
#   775: 'Bucket of wax',
#   776: 'Bucket',
#   777: 'Bullseye lantern (empty)',
#   778: 'Bullseye lantern (unf)',
#   779: 'Bullseye lantern',
#   780: 'Burning amulet(5)',
#   781: 'Burnt bones',
#   782: 'Burnt page',
#   783: 'Butterfly jar',
#   784: 'Butterfly net',
#   785: 'Cabbage round shield',
#   786: 'Cabbage seed',
#   787: 'Cabbage',
#   788: 'Cabbages(10)',
#   789: 'Cactus seed',
#   790: 'Cactus spine',
#   791: 'Cadantine blood potion (unf)',
#   792: 'Cadantine potion (unf)',
#   793: 'Cadantine seed',
#   794: 'Cadantine',
#   795: 'Cadava berries',
#   796: 'Cadavaberry seed',
#   797: 'Cake tin',
#   798: 'Cake',
#   799: 'Calcite',
#   800: 'Calquat fruit',
#   801: 'Calquat keg',
#   802: 'Calquat sapling',
#   803: 'Calquat tree seed',
#   804: 'Camelot teleport',
#   805: 'Candle lantern (white)',
#   806: 'Candle lantern (black)',
#   807: 'Candle',
#   808: 'Cannon barrels',
#   809: 'Cannon base',
#   810: 'Cannon furnace',
#   811: 'Cannon stand',
#   812: 'Cannonball',
#   813: 'Cape of skulls',
#   814: 'Carrallangar teleport',
#   815: 'Carved oak bench',
#   816: 'Carved oak magic wardrobe',
#   817: 'Carved oak table',
#   818: 'Carved teak bench',
#   819: 'Carved teak magic wardrobe',
#   820: 'Carved teak table',
#   821: 'Casket',
#   822: 'Castle wars bracelet(3)',
#   823: 'Cat mask',
#   824: 'Catherby teleport',
#   825: 'Cavalier mask',
#   826: 'Cave eel',
#   827: 'Cave goblin wire',
#   828: 'Caviar',
#   829: 'Celastrus bark',
#   830: 'Celastrus sapling',
#   831: 'Celastrus seed',
#   832: 'Cemetery teleport',
#   833: 'Chaos rune',
#   834: 'Chaos talisman',
#   835: 'Chaos tiara',
#   836: 'Charcoal',
#   837: 'Charge dragonstone jewellery scroll',
#   838: 'Cheese+tom batta',
#   839: 'Cheese',
#   840: "Chef's delight(4)",
#   841: "Chef's delight(m)",
#   842: "Chef's delight(m4)",
#   843: "Chef's delight",
#   844: "Chef's delight",
#   845: "Chef's hat",
#   846: 'Chilli con carne',
#   847: 'Chilli potato',
#   848: 'Chinchompa',
#   849: 'Chisel',
#   850: 'Choc saturday',
#   851: 'Choc-ice',
#   852: 'Chocchip crunchies',
#   853: 'Chocolate bar',
#   854: 'Chocolate bomb',
#   855: 'Chocolate cake',
#   856: 'Chocolate dust',
#   857: 'Chopped garlic',
#   858: 'Chopped onion',
#   859: 'Chopped tomato',
#   860: 'Chopped tuna',
#   861: 'Chopped ugthanki',
#   862: 'Christmas cracker',
#   863: 'Cider barrel',
#   864: 'Cider(4)',
#   865: 'Cider(m4)',
#   866: 'Cider',
#   867: 'Circular hide',
#   868: 'Citizen shoes',
#   869: 'Citizen top',
#   870: 'Citizen trousers',
#   871: 'Clay',
#   872: 'Cleaning cloth',
#   873: 'Cleaver',
#   874: 'Climbing boots',
#   875: 'Climbing boots (g)',
#   876: 'Clockwork',
#   877: 'Clue box',
#   878: 'Coal',
#   879: 'Cocktail glass',
#   880: 'Cocktail guide',
#   881: 'Cocktail shaker',
#   882: 'Coconut milk',
#   883: 'Coconut',
#   884: 'Cod',
#   885: 'Coif',
#   886: 'Combat bracelet(4)',
#   887: 'Combat bracelet(6)',
#   888: 'Combat bracelet',
#   889: 'Combat mix(1)',
#   890: 'Combat mix(2)',
#   891: 'Combat potion set',
#   892: 'Combat potion(1)',
#   893: 'Combat potion(2)',
#   894: 'Combat potion(3)',
#   895: 'Combat potion(4)',
#   896: 'Common kebbit fur',
#   897: 'Common tench',
#   898: 'Comp ogre bow',
#   899: 'Compost potion(1)',
#   900: 'Compost potion(2)',
#   901: 'Compost potion(3)',
#   902: 'Compost potion(4)',
#   903: 'Compost',
#   904: 'Cooked chicken',
#   905: 'Cooked chompy',
#   906: 'Cooked crab meat',
#   907: 'Cooked jubbly',
#   908: 'Cooked karambwan',
#   909: 'Cooked meat',
#   910: 'Cooked oomlie wrap',
#   911: 'Cooked rabbit',
#   912: 'Cooked slimy eel',
#   913: 'Cooked sweetcorn',
#   914: 'Cooking apple',
#   915: 'Copper ore',
#   916: 'Cornflour',
#   917: 'Cosmic rune',
#   918: 'Cosmic talisman',
#   919: 'Cosmic tiara',
#   920: 'Cowhide',
#   921: "Craw's bow (u)",
#   922: 'Cream boots',
#   923: 'Cream hat',
#   924: 'Cream robe bottoms',
#   925: 'Cream robe top',
#   926: 'Crier bell',
#   927: 'Crier coat',
#   928: 'Crier hat',
#   929: 'Crossbow string',
#   930: 'Crossbow',
#   931: 'Crude chair',
#   932: 'Crunchy tray',
#   933: 'Crushed nest',
#   934: 'Crushed superior dragon bones',
#   935: 'Crystal ball',
#   936: 'Crystal key',
#   937: 'Crystal of power',
#   938: 'Crystal weapon seed',
#   939: 'Cup of hot water',
#   940: 'Cup of tea',
#   941: 'Cup of water',
#   942: 'Cured yak-hide',
#   943: 'Curry leaf',
#   944: 'Curry sapling',
#   945: 'Curry tree seed',
#   946: 'Curry',
#   947: 'Cyclops head',
#   948: 'Dagannoth bones',
#   949: 'Dagannoth hide',
#   950: 'Damaged monkey tail',
#   951: 'Dareeyak teleport',
#   952: 'Dark bow tie',
#   953: 'Dark bow',
#   954: 'Dark cavalier',
#   955: 'Dark crab',
#   956: 'Dark fishing bait',
#   957: 'Dark infinity colour kit',
#   958: 'Dark kebbit fur',
#   959: 'Dark trousers',
#   960: 'Dark tuxedo cuffs',
#   961: 'Dark tuxedo jacket',
#   962: 'Dark tuxedo shoes',
#   963: 'Dashing kebbit fur',
#   964: 'Death rune',
#   965: 'Death talisman',
#   966: 'Death tiara',
#   967: 'Deerstalker',
#   968: 'Defence mix(1)',
#   969: 'Defence mix(2)',
#   970: 'Defence potion(1)',
#   971: 'Defence potion(2)',
#   972: 'Defence potion(3)',
#   973: 'Defence potion(4)',
#   974: 'Demon feet',
#   975: 'Desert boots',
#   976: 'Desert camo legs',
#   977: 'Desert camo top',
#   978: 'Desert devil fur',
#   979: 'Desert goat horn',
#   980: 'Desert legs',
#   981: 'Desert robe',
#   982: 'Desert robes',
#   983: 'Desert shirt',
#   984: 'Desert top',
#   985: 'Devout boots',
#   986: 'Dexterous prayer scroll',
#   987: "Dharok's armour set",
#   988: "Dharok's greataxe 0",
#   989: "Dharok's greataxe",
#   990: "Dharok's helm 0",
#   991: "Dharok's helm",
#   992: "Dharok's platebody 0",
#   993: "Dharok's platebody",
#   994: "Dharok's platelegs 0",
#   995: "Dharok's platelegs",
#   996: 'Diamond amulet (u)',
#   997: 'Diamond amulet',
#   998: 'Diamond bolt tips',
#   999: 'Diamond bolts (e)',
#   ...},
#  'Buy limit': {0: 8,
#   1: 40,
#   2: 8,
#   3: 8,
#   4: 8,
#   5: 4,
#   6: 4,
#   7: 8,
#   8: 8,
#   9: 8,
#   10: 8,
#   11: 8,
#   12: 40,
#   13: 8,
#   14: 8,
#   15: 8,
#   16: 8,
#   17: 8,
#   18: 8,
#   19: 8,
#   20: 8,
#   21: 8,
#   22: 8,
#   23: 4,
#   24: 8,
#   25: 10000,
#   26: 8,
#   27: 8,
#   28: 8,
#   29: 8,
#   30: 70,
#   31: 13000,
#   32: 200,
#   33: 125,
#   34: 11000,
#   35: 11000,
#   36: 11000,
#   37: 11000,
#   38: 10000,
#   39: 40,
#   40: 125,
#   41: 11000,
#   42: 11000,
#   43: 11000,
#   44: 13000,
#   45: 11000,
#   46: 125,
#   47: 11000,
#   48: 4,
#   49: 125,
#   50: 125,
#   51: 10000,
#   52: 70,
#   53: 125,
#   54: 125,
#   55: 125,
#   56: 125,
#   57: 20000,
#   58: 11000,
#   59: 11000,
#   60: 11000,
#   61: 11000,
#   62: 4,
#   63: 8,
#   64: 8,
#   65: 125,
#   66: 8,
#   67: 8,
#   68: 125,
#   69: 125,
#   70: 125,
#   71: 125,
#   72: 125,
#   73: 70,
#   74: 70,
#   75: 70,
#   76: 70,
#   77: 70,
#   78: 10000,
#   79: 11000,
#   80: 11000,
#   81: 11000,
#   82: 11000,
#   83: 8,
#   84: 8,
#   85: 125,
#   86: 11000,
#   87: 7000,
#   88: 7000,
#   89: 11000,
#   90: 125,
#   91: 125,
#   92: 125,
#   93: 40,
#   94: 8,
#   95: 8,
#   96: 8,
#   97: 8,
#   98: 8,
#   99: 8,
#   100: 8,
#   101: 125,
#   102: 8,
#   103: 8,
#   104: 125,
#   105: 8,
#   106: 8,
#   107: 125,
#   108: 125,
#   109: 8,
#   110: 8,
#   111: 70,
#   112: 70,
#   113: 70,
#   114: 70,
#   115: 70,
#   116: 125,
#   117: 125,
#   118: 125,
#   119: 125,
#   120: 125,
#   121: 125,
#   122: 11000,
#   123: 8,
#   124: 8,
#   125: 125,
#   126: 10000,
#   127: 10000,
#   128: 13000,
#   129: 4500,
#   130: 10000,
#   131: 4,
#   132: 2000,
#   133: 2000,
#   134: 2000,
#   135: 2000,
#   136: 2000,
#   137: 2000,
#   138: 8,
#   139: 15,
#   140: 15,
#   141: 15,
#   142: 15,
#   143: 15,
#   144: 15,
#   145: 15,
#   146: 15,
#   147: 18000,
#   148: 11000,
#   149: 50000,
#   150: 40,
#   151: 11000,
#   152: 15,
#   153: 4,
#   154: 11000,
#   155: 11000,
#   156: 11000,
#   157: 11000,
#   158: 11000,
#   159: 10000,
#   160: 11000,
#   161: 11000,
#   162: 10000,
#   163: 7000,
#   164: 7000,
#   165: 7000,
#   166: 11000,
#   167: 13000,
#   168: 40,
#   169: 5,
#   170: 8,
#   171: 10000,
#   172: 10000,
#   173: 4,
#   174: 125,
#   175: 5,
#   176: 8,
#   177: 5,
#   178: 5,
#   179: 5,
#   180: 10000,
#   181: 10000,
#   182: 10000,
#   183: 5,
#   184: 125,
#   185: 5,
#   186: 125,
#   187: 125,
#   188: 8,
#   189: 8,
#   190: 11000,
#   191: 8,
#   192: 8,
#   193: 8,
#   194: 5,
#   195: 15000,
#   196: 10000,
#   197: 5,
#   198: 8,
#   199: 8,
#   200: 8,
#   201: 8,
#   202: 8,
#   203: 250,
#   204: 8,
#   205: 8,
#   206: 8,
#   207: 8,
#   208: 250,
#   209: 250,
#   210: 8,
#   211: 8,
#   212: 8,
#   213: 250,
#   214: 8,
#   215: 5,
#   216: 5,
#   217: 5,
#   218: 5,
#   219: 8,
#   220: 8,
#   221: 8,
#   222: 250,
#   223: 8,
#   224: 8,
#   225: 8,
#   226: 8,
#   227: 70,
#   228: 250,
#   229: 8,
#   230: 250,
#   231: 8,
#   232: 10000,
#   233: 4,
#   234: 4,
#   235: 4,
#   236: 4,
#   237: 4,
#   238: 4,
#   239: 10000,
#   240: 125,
#   241: 2000,
#   242: 2000,
#   243: 2000,
#   244: 2000,
#   245: 2000,
#   246: 2000,
#   247: 2000,
#   248: 2000,
#   249: 2000,
#   250: 2000,
#   251: 2000,
#   252: 2000,
#   253: 4000,
#   254: 4000,
#   255: 4000,
#   256: 4000,
#   257: 4000,
#   258: 4000,
#   259: 4000,
#   260: 4000,
#   261: 2000,
#   262: 2000,
#   263: 2000,
#   264: 2000,
#   265: 2000,
#   266: 2000,
#   267: 2000,
#   268: 2000,
#   269: 2000,
#   270: 2000,
#   271: 2000,
#   272: 2000,
#   273: 10000,
#   274: 11000,
#   275: 10000,
#   276: 200,
#   277: 200,
#   278: 600,
#   279: 125,
#   280: 5,
#   281: 5,
#   282: 8,
#   283: 4,
#   284: 4,
#   285: 4,
#   286: 70,
#   287: 8,
#   288: 18000,
#   289: 11000,
#   290: 11000,
#   291: 10000,
#   292: 15,
#   293: 8,
#   294: 8,
#   295: 8,
#   296: 8,
#   297: 8,
#   298: 8,
#   299: 8,
#   300: 8,
#   301: 8,
#   302: 8,
#   303: 8,
#   304: 8,
#   305: 8,
#   306: 4,
#   307: 8,
#   308: 8,
#   309: 10000,
#   310: 8,
#   311: 8,
#   312: 5,
#   313: 5,
#   314: 5,
#   315: 5,
#   316: 8,
#   317: 8,
#   318: 8,
#   319: 8,
#   320: 8,
#   321: 8,
#   322: 8,
#   323: 8,
#   324: 7000,
#   325: 2000,
#   326: 2000,
#   327: 2000,
#   328: 2000,
#   329: 500,
#   330: 11000,
#   331: 2000,
#   332: 13000,
#   333: 150,
#   334: 10000,
#   335: 7500,
#   336: 2000,
#   337: 2000,
#   338: 2000,
#   339: 2000,
#   340: 2000,
#   341: 2000,
#   342: 10000,
#   343: 200,
#   344: 13000,
#   345: 8,
#   346: 2000,
#   347: 2000,
#   348: 2000,
#   349: 2000,
#   350: 18000,
#   351: 3000,
#   352: 8000,
#   353: 10000,
#   354: 10000,
#   355: 10000,
#   356: 10000,
#   357: 10000,
#   358: 10000,
#   359: 10000,
#   360: 10000,
#   361: 10000,
#   362: 10000,
#   363: 10000,
#   364: 10000,
#   365: 10000,
#   366: 10000,
#   367: 10000,
#   368: 10000,
#   369: 13000,
#   370: 13000,
#   371: 8,
#   372: 8,
#   373: 200,
#   374: 6000,
#   375: 200,
#   376: 13000,
#   377: 600,
#   378: 150,
#   379: 2000,
#   380: 8,
#   381: 8,
#   382: 8,
#   383: 8,
#   384: 8,
#   385: 8,
#   386: 8,
#   387: 8,
#   388: 8,
#   389: 8,
#   390: 8,
#   391: 8,
#   392: 4,
#   393: 8,
#   394: 10000,
#   395: 8,
#   396: 8,
#   397: 5,
#   398: 5,
#   399: 5,
#   400: 5,
#   401: 8,
#   402: 8,
#   403: 8,
#   404: 8,
#   405: 8,
#   406: 8,
#   407: 8,
#   408: 8,
#   409: 8,
#   410: 11000,
#   411: 40,
#   412: 10000,
#   413: 7000,
#   414: 13000,
#   415: 11000,
#   416: 2000,
#   417: 11000,
#   418: 15,
#   419: 10000,
#   420: 10000,
#   421: 8,
#   422: 10000,
#   423: 6000,
#   424: 2000,
#   425: 2000,
#   426: 2000,
#   427: 2000,
#   428: 3000,
#   429: 40,
#   430: 10000,
#   431: 2000,
#   432: 2000,
#   433: 2000,
#   434: 2000,
#   435: 11000,
#   436: 4,
#   437: 4,
#   438: 18000,
#   439: 500,
#   440: 10000,
#   441: 2000,
#   442: 2000,
#   443: 125,
#   444: 200,
#   445: 70,
#   446: 4,
#   447: 70,
#   448: 8,
#   449: 3000,
#   450: 40,
#   451: 4,
#   452: 10000,
#   453: 250,
#   454: 11000,
#   455: 250,
#   456: 125,
#   457: 40,
#   458: 125,
#   459: 11000,
#   460: 4,
#   461: 4,
#   462: 125,
#   463: 11000,
#   464: 4,
#   465: 150,
#   466: 4,
#   467: 125,
#   468: 11000,
#   469: 125,
#   470: 8,
#   471: 8,
#   472: 70,
#   473: 8,
#   474: 8,
#   475: 70,
#   476: 125,
#   477: 70,
#   478: 125,
#   479: 125,
#   480: 125,
#   481: 125,
#   482: 7000,
#   483: 7000,
#   484: 7000,
#   485: 7000,
#   486: 4,
#   487: 15,
#   488: 15,
#   489: 11000,
#   490: 4,
#   491: 70,
#   492: 11000,
#   493: 4,
#   494: 4,
#   495: 150,
#   496: 8,
#   497: 8,
#   498: 125,
#   499: 8,
#   500: 8,
#   501: 125,
#   502: 4,
#   503: 70,
#   504: 70,
#   505: 70,
#   506: 70,
#   507: 70,
#   508: 8,
#   509: 8,
#   510: 125,
#   511: 7000,
#   512: 7000,
#   513: 7000,
#   514: 7000,
#   515: 4,
#   516: 125,
#   517: 125,
#   518: 70,
#   519: 70,
#   520: 125,
#   521: 13000,
#   522: 4,
#   523: 8,
#   524: 8,
#   525: 8,
#   526: 8,
#   527: 8,
#   528: 8,
#   529: 8,
#   530: 125,
#   531: 8,
#   532: 8,
#   533: 125,
#   534: 8,
#   535: 8,
#   536: 125,
#   537: 125,
#   538: 125,
#   539: 125,
#   540: 8,
#   541: 8,
#   542: 70,
#   543: 70,
#   544: 70,
#   545: 70,
#   546: 70,
#   547: 4,
#   548: 4,
#   549: 150,
#   550: 8,
#   551: 8,
#   552: 8,
#   553: 8,
#   554: 125,
#   555: 125,
#   556: 125,
#   557: 5,
#   558: 150,
#   559: 8,
#   560: 8,
#   561: 4,
#   562: 125,
#   563: 125,
#   564: 4,
#   565: 4,
#   566: 4,
#   567: 4,
#   568: 125,
#   569: 13000,
#   570: 13000,
#   571: 13000,
#   572: 13000,
#   573: 13000,
#   574: 8,
#   575: 25000,
#   576: 150,
#   577: 2000,
#   578: 4,
#   579: 4,
#   580: 150,
#   581: 150,
#   582: 8,
#   583: 8,
#   584: 125,
#   585: 8,
#   586: 8,
#   587: 125,
#   588: 125,
#   589: 125,
#   590: 4,
#   591: 13000,
#   592: 4,
#   593: 13000,
#   594: 125,
#   595: 13000,
#   596: 150,
#   597: 4,
#   598: 4,
#   599: 4,
#   600: 4,
#   601: 8000,
#   602: 250,
#   603: 150,
#   604: 5,
#   605: 150,
#   606: 4,
#   607: 5,
#   608: 150,
#   609: 150,
#   610: 4,
#   611: 4,
#   612: 150,
#   613: 125,
#   614: 4,
#   615: 4,
#   616: 125,
#   617: 4,
#   618: 4,
#   619: 125,
#   620: 13000,
#   621: 2000,
#   622: 4,
#   623: 4,
#   624: 4,
#   625: 4,
#   626: 4,
#   627: 12000,
#   628: 11000,
#   629: 40,
#   630: 40,
#   631: 13000,
#   632: 11000,
#   633: 11000,
#   634: 4,
#   635: 70,
#   636: 70,
#   637: 70,
#   638: 70,
#   639: 4,
#   640: 10000,
#   641: 10000,
#   642: 3000,
#   643: 5,
#   644: 5,
#   645: 5,
#   646: 5,
#   647: 500,
#   648: 70,
#   649: 70,
#   650: 125,
#   651: 10000,
#   652: 10000,
#   653: 50,
#   654: 50,
#   655: 5,
#   656: 5,
#   657: 13000,
#   658: 13000,
#   659: 13000,
#   660: 4,
#   661: 13000,
#   662: 250,
#   663: 40,
#   664: 10000,
#   665: 10000,
#   666: 10000,
#   667: 13000,
#   668: 150,
#   669: 15,
#   670: 13000,
#   671: 6000,
#   672: 4,
#   673: 8,
#   674: 8,
#   675: 7000,
#   676: 7000,
#   677: 150,
#   678: 70,
#   679: 125,
#   680: 7000,
#   681: 7000,
#   682: 7000,
#   683: 7000,
#   684: 10000,
#   685: 40,
#   686: 10000,
#   687: 125,
#   688: 11000,
#   689: 11000,
#   690: 11000,
#   691: 13000,
#   692: 7000,
#   693: 125,
#   694: 11000,
#   695: 125,
#   696: 125,
#   697: 10000,
#   698: 125,
#   699: 125,
#   700: 125,
#   701: 125,
#   702: 125,
#   703: 13000,
#   704: 7000,
#   705: 7000,
#   706: 7000,
#   707: 7000,
#   708: 4,
#   709: 4,
#   710: 4,
#   711: 125,
#   712: 8,
#   713: 8,
#   714: 125,
#   715: 125,
#   716: 125,
#   717: 125,
#   718: 125,
#   719: 10000,
#   720: 7000,
#   721: 7000,
#   722: 7000,
#   723: 7000,
#   724: 4,
#   725: 4,
#   726: 125,
#   727: 7000,
#   728: 7000,
#   729: 7000,
#   730: 7000,
#   731: 10000,
#   732: 125,
#   733: 125,
#   734: 125,
#   735: 13000,
#   736: 40,
#   737: 4,
#   738: 4,
#   739: 125,
#   740: 4,
#   741: 4,
#   742: 125,
#   743: 4,
#   744: 4,
#   745: 125,
#   746: 125,
#   747: 8,
#   748: 8,
#   749: 125,
#   750: 125,
#   751: 125,
#   752: 125,
#   753: 125,
#   754: 125,
#   755: 7000,
#   756: 8,
#   757: 8,
#   758: 125,
#   759: 15,
#   760: 125,
#   761: 125,
#   762: 40,
#   763: 4,
#   764: 150,
#   765: 150,
#   766: 100,
#   767: 8,
#   768: 8,
#   769: 4,
#   770: 4,
#   771: 13000,
#   772: 13000,
#   773: 15,
#   774: 13000,
#   775: 15,
#   776: 13000,
#   777: 10000,
#   778: 10000,
#   779: 10000,
#   780: 10000,
#   781: 3000,
#   782: 11000,
#   783: 40,
#   784: 125,
#   785: 125,
#   786: 600,
#   787: 6000,
#   788: 600,
#   789: 200,
#   790: 11000,
#   791: 10000,
#   792: 10000,
#   793: 200,
#   794: 11000,
#   795: 600,
#   796: 600,
#   797: 40,
#   798: 6000,
#   799: 13000,
#   800: 11000,
#   801: 10000,
#   802: 200,
#   803: 200,
#   804: 10000,
#   805: 40,
#   806: 100,
#   807: 40,
#   808: 70,
#   809: 70,
#   810: 70,
#   811: 70,
#   812: 11000,
#   813: 8,
#   814: 10000,
#   815: 500,
#   816: 500,
#   817: 500,
#   818: 500,
#   819: 500,
#   820: 500,
#   821: 50,
#   822: 10000,
#   823: 4,
#   824: 10000,
#   825: 150,
#   826: 10000,
#   827: 11000,
#   828: 13000,
#   829: 12000,
#   830: 200,
#   831: 200,
#   832: 10000,
#   833: 12000,
#   834: 11000,
#   835: 40,
#   836: 13000,
#   837: 10000,
#   838: 6000,
#   839: 13000,
#   840: 2000,
#   841: 2000,
#   842: 2000,
#   843: 2000,
#   844: 500,
#   845: 150,
#   846: 13000,
#   847: 13000,
#   848: 7000,
#   849: 40,
#   850: 2000,
#   851: 6000,
#   852: 6000,
#   853: 13000,
#   854: 6000,
#   855: 6000,
#   856: 13000,
#   857: 13000,
#   858: 11000,
#   859: 11000,
#   860: 13000,
#   861: 11000,
#   862: 50,
#   863: 500,
#   864: 2000,
#   865: 2000,
#   866: 2000,
#   867: 11000,
#   868: 150,
#   869: 150,
#   870: 150,
#   871: 13000,
#   872: 40,
#   873: 50,
#   874: 200,
#   875: 4,
#   876: 11000,
#   877: 50,
#   878: 13000,
#   879: 13000,
#   880: 15,
#   881: 40,
#   882: 11000,
#   883: 11000,
#   884: 6000,
#   885: 125,
#   886: 10000,
#   887: 10000,
#   888: 10000,
#   889: 2000,
#   890: 2000,
#   891: 2000,
#   892: 2000,
#   893: 2000,
#   894: 2000,
#   895: 2000,
#   896: 10000,
#   897: 13000,
#   898: 70,
#   899: 50,
#   900: 50,
#   901: 50,
#   902: 50,
#   903: 2000,
#   904: 6000,
#   905: 6000,
#   906: 6000,
#   907: 10000,
#   908: 10000,
#   909: 6000,
#   910: 15,
#   911: 6000,
#   912: 6000,
#   913: 11000,
#   914: 13000,
#   915: 13000,
#   916: 15,
#   917: 12000,
#   918: 11000,
#   919: 40,
#   920: 13000,
#   921: 8,
#   922: 150,
#   923: 150,
#   924: 150,
#   925: 150,
#   926: 4,
#   927: 4,
#   928: 4,
#   929: 11000,
#   930: 125,
#   931: 500,
#   932: 40,
#   933: 11000,
#   934: 11000,
#   935: 500,
#   936: 11000,
#   937: 500,
#   938: 70,
#   939: 13000,
#   940: 2000,
#   941: 13000,
#   942: 13000,
#   943: 11000,
#   944: 200,
#   945: 200,
#   946: 10000,
#   947: 4,
#   948: 7500,
#   949: 11000,
#   950: 13000,
#   951: 10000,
#   952: 4,
#   953: 8,
#   954: 4,
#   955: 10000,
#   956: 8000,
#   957: 4,
#   958: 10000,
#   959: 4,
#   960: 4,
#   961: 4,
#   962: 4,
#   963: 10000,
#   964: 25000,
#   965: 11000,
#   966: 40,
#   967: 4,
#   968: 2000,
#   969: 2000,
#   970: 2000,
#   971: 2000,
#   972: 2000,
#   973: 2000,
#   974: 4,
#   975: 150,
#   976: 150,
#   977: 150,
#   978: 10000,
#   979: 13000,
#   980: 150,
#   981: 150,
#   982: 150,
#   983: 150,
#   984: 150,
#   985: 70,
#   986: 5,
#   987: 8,
#   988: 15,
#   989: 15,
#   990: 15,
#   991: 15,
#   992: 15,
#   993: 15,
#   994: 15,
#   995: 15,
#   996: 10000,
#   997: 10000,
#   998: 11000,
#   999: 11000,
#   ...}}

# %%
#write the corrected file

corrected_dict = {}
for i in range(len(foo["Item"])):
    #name = f'"{foo["Item"][i]}"'
    name = r'\"{}\"'.format(foo["Item"][i])
    #limit = f'"{foo["Buy limit"][i]}"'
    limit = r'\"{}\"'.format(foo["Buy limit"][i])
    corrected_dict[name] = int(limit)

corrected_dict
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-3588863da846> in <module>
#       5     #limit = f'"{foo["Buy limit"][i]}"'
#       6     limit = r'\"{}\"'.format(foo["Buy limit"][i])
# ----> 7     corrected_dict[name] = int(limit)
#       8
#       9 corrected_dict
#
# ValueError: invalid literal for int() with base 10: '\\"8\\"'

# %%
f = open("corrected-item-buylimits.json", 'w')
f.write(str(corrected_dict))
f.close()

# %%
#upload the corrected file to the branch

# %%
#write a simple test for the values you know to be broken
